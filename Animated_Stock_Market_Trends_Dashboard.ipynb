# %% [markdown]
# 🎬 Project Title: Animated Stock Market Trends Dashboard

# %% [markdown]
# # Stock Market Animated Visualizations with Plotly

# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# # Load dataset

# %%
df = pd.read_csv("stock_data.csv", parse_dates=['Date'])

# %% [markdown]
# # 1. Animated Line Chart - Stock Price Trend Over Time

# %%
fig1 = px.line(df, x='Date', y='Close', color='Company',
               title='Animated Stock Price Trend',
               animation_frame='Date')
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="40e4a363-9a36-42e3-bd53-d868f6098223" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("40e4a363-9a36-42e3-bd53-d868f6098223")) {                    Plotly.newPlot(                        "40e4a363-9a36-42e3-bd53-d868f6098223",                        [{"hovertemplate":"Company=Apple\u003cbr\u003eDate=%{x}\u003cbr\u003eClose=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Apple","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Apple","orientation":"v","showlegend":true,"x":["2024-01-01T00:00:00"],"xaxis":"x","y":[311.63],"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=Amazon\u003cbr\u003eDate=%{x}\u003cbr\u003eClose=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Amazon","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Amazon","orientation":"v","showlegend":true,"x":["2024-01-01T00:00:00"],"xaxis":"x","y":[395.85],"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=Google\u003cbr\u003eDate=%{x}\u003cbr\u003eClose=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Google","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Google","orientation":"v","showlegend":true,"x":["2024-01-01T00:00:00"],"xaxis":"x","y":[280.57],"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=Tesla\u003cbr\u003eDate=%{x}\u003cbr\u003eClose=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tesla","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Tesla","orientation":"v","showlegend":true,"x":["2024-01-01T00:00:00"],"xaxis":"x","y":[211.52],"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=Microsoft\u003cbr\u003eDate=%{x}\u003cbr\u003eClose=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Microsoft","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Microsoft","orientation":"v","showlegend":true,"x":["2024-01-01T00:00:00"],"xaxis":"x","y":[172.77],"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=Walmart\u003cbr\u003eDate=%{x}\u003cbr\u003eClose=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Walmart","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Walmart","orientation":"v","showlegend":true,"x":["2024-01-01T00:00:00"],"xaxis":"x","y":[191.32],"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=Netflix\u003cbr\u003eDate=%{x}\u003cbr\u003eClose=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Netflix","line":{"color":"#FF6692","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Netflix","orientation":"v","showlegend":true,"x":["2024-01-01T00:00:00"],"xaxis":"x","y":[433.61],"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=Meta\u003cbr\u003eDate=%{x}\u003cbr\u003eClose=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Meta","line":{"color":"#B6E880","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Meta","orientation":"v","showlegend":true,"x":["2024-01-01T00:00:00"],"xaxis":"x","y":[324.92],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}], ...

# %% [markdown]
# # 2. Bar Race - Top Companies by Volume

# %%
volume_by_day = df.groupby(['Date', 'Company'])['Volume'].sum().reset_index()
fig2 = px.bar(volume_by_day.sort_values(['Date', 'Volume'], ascending=[True, False]),
              x='Volume', y='Company', color='Company',
              animation_frame='Date', orientation='h',
              title='Daily Top Companies by Trading Volume')
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c3c4932d-d73d-429d-ac36-f061799dc412" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c3c4932d-d73d-429d-ac36-f061799dc412")) {                    Plotly.newPlot(                        "c3c4932d-d73d-429d-ac36-f061799dc412",                        [{"alignmentgroup":"True","hovertemplate":"Company=%{y}\u003cbr\u003eDate=2024-01-01 00:00:00\u003cbr\u003eVolume=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Meta","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Meta","offsetgroup":"Meta","orientation":"h","showlegend":true,"textposition":"auto","x":[130174821],"xaxis":"x","y":["Meta"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Company=%{y}\u003cbr\u003eDate=2024-01-01 00:00:00\u003cbr\u003eVolume=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Apple","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Apple","offsetgroup":"Apple","orientation":"h","showlegend":true,"textposition":"auto","x":[100776238],"xaxis":"x","y":["Apple"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Company=%{y}\u003cbr\u003eDate=2024-01-01 00:00:00\u003cbr\u003eVolume=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Walmart","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Walmart","offsetgroup":"Walmart","orientation":"h","showlegend":true,"textposition":"auto","x":[93008406],"xaxis":"x","y":["Walmart"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Company=%{y}\u003cbr\u003eDate=2024-01-01 00:00:00\u003cbr\u003eVolume=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Netflix","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Netflix","offsetgroup":"Netflix","orientation":"h","showlegend":true,"textposition":"auto","x":[61336853],"xaxis":"x","y":["Netflix"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Company=%{y}\u003cbr\u003eDate=2024-01-01 00:00:00\u003cbr\u003eVolume=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Google","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Google","offsetgroup":"Google","orientation":"h","showlegend":true,"textposition":"auto","x":[42983269],"xaxis":"x","y":["Google"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Company=%{y}\u003cbr\u003eDate=2024-01-01 00:00:00\u003cbr\u003eVolume=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Microsoft","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Microsoft","offsetgroup":"Microsoft","orientation":"h","showlegend":true,"textposition":"auto","x":[40738619],"xaxis":"x","y":["Microsoft"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Company=%{y}\u003cbr\u003eDate=2024-01-01 00:00:00\u003cbr\u003eVolume=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Amazon","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Amazon","offsetgroup":"Amazon","orientation":"h","showlegend":true,"textposition":"auto","x":[38859939],"xaxis":"x","y":["Amazon"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Company=%{y}\u003cbr\u003eDate=2024-01-01 00:00:00\u003cbr\u003eVolume=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tesla","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Tesla","offsetgroup":"Tesla","orientation":"h","showlegend":true,"textposition":"auto","x":[37326495],"xaxis":"x","y":["Tesla"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.33333 ...

# %% [markdown]
# # 3. Animated Bubble Plot - Volume vs Price per Sector

# %%
avg_price = (df['High'] + df['Low']) / 2
df['AvgPrice'] = avg_price
fig3 = px.scatter(df, x='AvgPrice', y='Volume', size='Volume', color='Sector',
                  animation_frame='Date', hover_name='Company',
                  title='Bubble Plot: Avg Price vs Volume by Sector')
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="93c50cce-977c-44d8-af81-009e78e9894a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("93c50cce-977c-44d8-af81-009e78e9894a")) {                    Plotly.newPlot(                        "93c50cce-977c-44d8-af81-009e78e9894a",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eSector=Technology\u003cbr\u003eDate=2024-01-01 00:00:00\u003cbr\u003eAvgPrice=%{x}\u003cbr\u003eVolume=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Apple","Google","Microsoft"],"legendgroup":"Technology","marker":{"color":"#636efa","size":[100776238,42983269,40738619],"sizemode":"area","sizeref":374895.5875,"symbol":"circle"},"mode":"markers","name":"Technology","orientation":"v","showlegend":true,"x":[305.235,279.28,169.12],"xaxis":"x","y":[100776238,42983269,40738619],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eSector=E-commerce\u003cbr\u003eDate=2024-01-01 00:00:00\u003cbr\u003eAvgPrice=%{x}\u003cbr\u003eVolume=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Amazon"],"legendgroup":"E-commerce","marker":{"color":"#EF553B","size":[38859939],"sizemode":"area","sizeref":374895.5875,"symbol":"circle"},"mode":"markers","name":"E-commerce","orientation":"v","showlegend":true,"x":[398.44],"xaxis":"x","y":[38859939],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eSector=Automotive\u003cbr\u003eDate=2024-01-01 00:00:00\u003cbr\u003eAvgPrice=%{x}\u003cbr\u003eVolume=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Tesla"],"legendgroup":"Automotive","marker":{"color":"#00cc96","size":[37326495],"sizemode":"area","sizeref":374895.5875,"symbol":"circle"},"mode":"markers","name":"Automotive","orientation":"v","showlegend":true,"x":[215.28],"xaxis":"x","y":[37326495],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eSector=Retail\u003cbr\u003eDate=2024-01-01 00:00:00\u003cbr\u003eAvgPrice=%{x}\u003cbr\u003eVolume=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Walmart"],"legendgroup":"Retail","marker":{"color":"#ab63fa","size":[93008406],"sizemode":"area","sizeref":374895.5875,"symbol":"circle"},"mode":"markers","name":"Retail","orientation":"v","showlegend":true,"x":[194.44],"xaxis":"x","y":[93008406],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eSector=Entertainment\u003cbr\u003eDate=2024-01-01 00:00:00\u003cbr\u003eAvgPrice=%{x}\u003cbr\u003eVolume=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Netflix"],"legendgroup":"Entertainment","marker":{"color":"#FFA15A","size":[61336853],"sizemode":"area","sizeref":374895.5875,"symbol":"circle"},"mode":"markers","name":"Entertainment","orientation":"v","showlegend":true,"x":[428.32500000000005],"xaxis":"x","y":[61336853],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eSector=Social Media\u003cbr\u003eDate=2024-01-01 00:00:00\u003cbr\u003eAvgPrice=%{x}\u003cbr\u003eVolume=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Meta"],"legendgroup":"Social Media","marker":{"color":"#19d3f3","size":[130174821],"sizemode":"area","sizeref":374895.5875,"symbol":"circle"},"mode":"markers","name":"Social Media","orientation":"v","showlegend":true,"x":[321.61],"xaxis":"x","y":[130174821],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour ...

# %% [markdown]
# # 4. Animated Treemap - Volume by Sector and Company

# %%
# Filter the latest date (or any specific date)
latest_date = tree_data['Date'].max()
latest_data = tree_data[tree_data['Date'] == latest_date]

# Plot treemap
fig4 = px.treemap(latest_data, path=['Sector', 'Company'], values='Volume',
                  title=f'Treemap of Volume by Sector & Company on {latest_date}')
fig4.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6b5e8855-4072-437c-ae0b-e80e97a652b2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6b5e8855-4072-437c-ae0b-e80e97a652b2")) {                    Plotly.newPlot(                        "6b5e8855-4072-437c-ae0b-e80e97a652b2",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003eVolume=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["E-commerce\u002fAmazon","Technology\u002fApple","Technology\u002fGoogle","Social Media\u002fMeta","Technology\u002fMicrosoft","Entertainment\u002fNetflix","Automotive\u002fTesla","Retail\u002fWalmart","Automotive","E-commerce","Entertainment","Retail","Social Media","Technology"],"labels":["Amazon","Apple","Google","Meta","Microsoft","Netflix","Tesla","Walmart","Automotive","E-commerce","Entertainment","Retail","Social Media","Technology"],"name":"","parents":["E-commerce","Technology","Technology","Social Media","Technology","Entertainment","Automotive","Retail","","","","","",""],"values":[41525217,71567584,62986397,76842846,101031370,1672908,42523540,136285235,42523540,41525217,1672908,136285235,76842846,235585351],"type":"treemap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"m ...

# %% [markdown]
# # 5. Animated Sunburst Chart - Sector > Company > Daily Volume

# %%
# Get the latest date
latest_date = tree_data['Date'].max()

# Filter data for the latest date
latest_data = tree_data[tree_data['Date'] == latest_date]

# Create sunburst chart
fig5 = px.sunburst(latest_data, path=['Sector', 'Company'], values='Volume',
                   title=f'Sunburst of Volume by Sector & Company on {latest_date}')
fig5.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5fa450d3-2502-427a-b03e-963f66d4d94a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5fa450d3-2502-427a-b03e-963f66d4d94a")) {                    Plotly.newPlot(                        "5fa450d3-2502-427a-b03e-963f66d4d94a",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003eVolume=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["E-commerce\u002fAmazon","Technology\u002fApple","Technology\u002fGoogle","Social Media\u002fMeta","Technology\u002fMicrosoft","Entertainment\u002fNetflix","Automotive\u002fTesla","Retail\u002fWalmart","Automotive","E-commerce","Entertainment","Retail","Social Media","Technology"],"labels":["Amazon","Apple","Google","Meta","Microsoft","Netflix","Tesla","Walmart","Automotive","E-commerce","Entertainment","Retail","Social Media","Technology"],"name":"","parents":["E-commerce","Technology","Technology","Social Media","Technology","Entertainment","Automotive","Retail","","","","","",""],"values":[41525217,71567584,62986397,76842846,101031370,1672908,42523540,136285235,42523540,41525217,1672908,136285235,76842846,235585351],"type":"sunburst"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":" ...
